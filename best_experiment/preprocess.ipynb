# %%
import pandas as pd
import numpy as np
from scipy.stats import zscore
from sklearn.impute import KNNImputer

# %%
file_path = r'.\raw_data\boy or girl 2024 test no ans_missingValue.csv'
data = pd.read_csv(file_path)
data
# Out:
#       id  gender star_sign phone_os  height  weight  sleepiness  iq  \
# 0      1       0       天蠍座    Apple     NaN     100           1  87
# 1      2       0       金牛座    Apple     175      80           3 130
# 2      3       0       雙子座    Apple     155      45           3 150
# 3      4       0       處女座    Apple     173      85           4 100
# 4      5       0       射手座  Android     164      57           4 130
# ..   ...     ...       ...      ...     ...     ...         ...  ..
# 390  391       0       處女座  Android     160      48           3  75
# 391  392       0       NaN    Apple     170     NaN         NaN 105
# 392  393       0       金牛座    Apple     160      45           4 100
# 393  394       0       巨蟹座      NaN     180     NaN         NaN 200
# 394  395       0       射手座    Apple     175      69           5 135
#
#      fb_friends      yt                                         self_intro
# 0            87      87                                               GOod
# 1       2.0E+03      30                                          Easygoing
# 2           400       9                                       I LOVE INTEL
# 3       2.0E+03      15  I'm a hard-work man, just do my best to finish...
# 4           505       2                                          I'm smart
# ..          ...     ...                                                ...
# 390          98       2                               Starting by Starting
# 391         510     NaN                                 A little bit smart
# 392         600 2.0E+03                                                 Hi
# 393         NaN      60                     I'm not beautiful, but smart 😀
# 394         200 1.4E+03                                    Like the shadow
#
# [395 rows x 11 columns]

# %%
# 星座的映射字典
star_sign_mapping = {
    '水瓶座': 0,
    '雙魚座': 1,
    '牡羊座': 2,
    '金牛座': 3,
    '雙子座': 4,
    '巨蟹座': 5,
    '獅子座': 6,
    '處女座': 7,
    '天秤座': 8,
    '天蠍座': 9,
    '射手座': 10,
    '摩羯座': 11
}

# 將星座欄位轉換為數字
data['star_sign'] = data['star_sign'].map(star_sign_mapping)

# 手機操作系統的映射字典
phone_os_mapping = {
    'Apple': 0,
    'Android': 1,
    'Windows phone': 2  
}

# 將手機操作系統欄位轉換為數字
data['phone_os'] = data['phone_os'].map(phone_os_mapping)

# 輸出處理後的測試資料集
data
# Out:
#       id  gender  star_sign  phone_os  height  weight  sleepiness  iq  \
# 0      1       0          9         0     NaN     100           1  87
# 1      2       0          3         0     175      80           3 130
# 2      3       0          4         0     155      45           3 150
# 3      4       0          7         0     173      85           4 100
# 4      5       0         10         1     164      57           4 130
# ..   ...     ...        ...       ...     ...     ...         ...  ..
# 390  391       0          7         1     160      48           3  75
# 391  392       0        NaN         0     170     NaN         NaN 105
# 392  393       0          3         0     160      45           4 100
# 393  394       0          5       NaN     180     NaN         NaN 200
# 394  395       0         10         0     175      69           5 135
#
#      fb_friends      yt                                         self_intro
# 0            87      87                                               GOod
# 1       2.0E+03      30                                          Easygoing
# 2           400       9                                       I LOVE INTEL
# 3       2.0E+03      15  I'm a hard-work man, just do my best to finish...
# 4           505       2                                          I'm smart
# ..          ...     ...                                                ...
# 390          98       2                               Starting by Starting
# 391         510     NaN                                 A little bit smart
# 392         600 2.0E+03                                                 Hi
# 393         NaN      60                     I'm not beautiful, but smart 😀
# 394         200 1.4E+03                                    Like the shadow
#
# [395 rows x 11 columns]

# %%
def calculate_bmi(height, weight):
    return weight / ((height/100) ** 2)

# %%
data['yt'] = pd.to_numeric(data['yt'], errors='coerce')

# %%
# 設置 pandas 顯示格式
pd.set_option('display.float_format', lambda x: '%.1E' % x if abs(x) > 1000 else '%.0f' % x)

# 欄位不包含 'id' 和 'self_intro'
columns_to_check = [col for col in data.columns if col not in ['id', 'self_intro']]

# 初始化計數器
total_outliers = 0
outliers_gender_1 = 0
outliers_gender_2 = 0

# 找出有outlier的資料
outliers = []
for index, row in data.iterrows():
    is_outlier = False
    for col in columns_to_check:
        # 如果該欄位是負值，則視為outlier
        if row[col] < 0:
            is_outlier = True
            break
        # 如果該欄位的數值過大，則視為outlier
        if col in ['height'] and (row[col] > 220 or row[col] < 140):  # 可以自行調整數值範圍
            is_outlier = True
            break
        
        if col in ['weight'] and (row[col] > 150 or row[col] < 30):  # 可以自行調整數值範圍
            is_outlier = True
            break

        if col in ['fb_friends'] and row[col] > 10000:  # 可以自行調整數值範圍
            is_outlier = True
            break

        if col in ['yt'] and row[col] > 5000:  # 可以自行調整數值範圍
            is_outlier = True
            break

        if col in ['bmi'] and (row[col] > 40 or row[col]<10):
            is_outlier = True
            break

        # 計算z-score
        z_score = zscore([row[col]])[0]
        # 如果z-score的絕對值大於3，則視為outlier
        if abs(z_score) > 3:
            is_outlier = True
            break

    if is_outlier:
        outliers.append(index)

        total_outliers += 1
        if row['gender'] == 1:
            outliers_gender_1 += 1
        elif row['gender'] == 2:
            outliers_gender_2 += 1

# 列印出有outlier的資料
if outliers:
    print("有outlier的資料:")
    print(data.loc[outliers])
else:
    print("沒有outlier的資料")

# 列印出outlier的總筆數和gender為1和2的outlier筆數
print("Outlier的總筆數:", total_outliers)
print("Gender為1的Outlier筆數:", outliers_gender_1)
print("Gender為2的Outlier筆數:", outliers_gender_2)

outliers_csv = pd.DataFrame(data.loc[outliers])


def replace_outliers_with_nan(data, index, column):
    # 找到 outlier 值的索引
    outlier_value = data.loc[index, column]

    # 將 outlier 值替換為 NaN
    data.at[index, column] = np.nan

    return data

def handle_outliers_and_impute(data, gender):
    # 取得指定性別的資料索引
    gender_indices = data[data['gender'] == gender].index.tolist()

    # 移除非數值型態的欄位
    numeric_cols = data.select_dtypes(include=['number']).columns.tolist()
    cleaned_data = data[numeric_cols]

    # 使用KNN補值
    imputer = KNNImputer(n_neighbors=5)
    imputed_data = cleaned_data.copy()
    imputed_data.loc[gender_indices] = imputer.fit_transform(imputed_data.loc[gender_indices])

    return imputed_data

# 將 outlier 替換為 NaN
data = replace_outliers_with_nan(data, index='your_index', column='your_column')

# 根據性別分別處理缺失值並用 KNN 補值
data_gender_1 = handle_outliers_and_impute(data[data['gender'] == 1], 1)
data_gender_2 = handle_outliers_and_impute(data[data['gender'] == 2], 2)

# 將處理後的資料合併回原始資料集
data_imputed = pd.concat([data_gender_1, data_gender_2])

# 顯示處理後的資料
data_imputed

# data.to_csv(r"C:\Users\Hank\BoyorGirl\BoyorGirl\KNN\outlier_detect\dataset_without_outlier_by_KNN.csv", index=False)
# Out:
# 有outlier的資料:
#       id  gender  star_sign  phone_os  height  weight  sleepiness  iq  \
# 15    16       0        NaN         1     188      20         NaN  88
# 51    52       0          4         2      88      88           1  87
# 61    62       0          9         1     170       1           4  50
# 64    65       0          7         0     166      90           1 170
# 88    89       0          8         1 2.0E+05 4.5E+05           2 180
# 92    93       0          5         0 1.8E+21 1.8E+30           1 200
# 121  122       0          6         0     160      50           4 180
# 126  127       0          2         1      52      29           1  51
# 128  129       0         11         0     174     888           1  50
# 140  141       0          3         1     166      66           5 100
# 157  158       0          4         0     171      66           5 199
# 161  162       0          2         0     172      56           2 200
# 181  182       0          5         1     170      25           2 200
# 188  189       0          0         0       0       0           1  50
# 196  197       0          7         1     175      65           2 180
# 211  212       0          9         0     171      73           2 200
# 219  220       0          7         0     159      45           3 122
# 222  223       0          1         0     380     380           5  60
# 223  224       0        NaN         1     183      70           5 NaN
# 231  232       0          9         0 1.2E+04     400           3  90
# 265  266       0          8         0     176     999           1 199
# 270  271       0          8         1     163       1           2 111
# 279  280       0          5         0     166       0           4 100
# 307  308       0          1         1     NaN       3           1 200
# 329  330       0          7         0     173      75           1  80
# 354  355       0          9         1     155       0           2 135
#
#      fb_friends      yt                                   self_intro
# 15          NaN     NaN                                 A young girl
# 51           87      87                                      Nothing
# 61            1 5.0E+03                                Reallll sheet
# 64      2.0E+04       0                                          ass
# 88      3.4E+08       0                                 I am so cute
# 92      1.0E+28       8                   Plz do not delete my data.
# 121          99 1.0E+04                         My Life , My Style .
# 126           4     970                                          TxT
# 128           1      40                   I don’t understand myself.
# 140         NaN 1.5E+04                         Absolutely fantastic
# 157     1.0E+05      20                         Live with your faith
# 161     1.0E+05     666                                    Ggininder
# 181           0     500                                        Smart
# 188           0       0                                          NaN
# 196     1.0E+98 1.0E+22                       who am i , loser life.
# 211     1.0E+05       1                                      Awesome
# 219           0 1.1E+10                                     I am fat
# 222           0     500                                       random
# 223         NaN 6.7E+03                                    Boiiiiiii
# 231         700      52                                       Person
# 265         500      30  quite handsome, quite sexy and longggg dxxk
# 270         190       0                                        >.0啾咪
# 279         200       1                                     positive
# 307         NaN       0                                  Go Pikachu!
# 329         130 3.0E+04                             I am a happy guy
# 354         350      12                                     adorable
# Outlier的總筆數: 26
# Gender為1的Outlier筆數: 0
# Gender為2的Outlier筆數: 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File D:\Anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'your_column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 98
#      95     return imputed_data
#      97 # 將 outlier 替換為 NaN
# ---> 98 data = replace_outliers_with_nan(data, index='your_index', column='your_column')
#     100 # 根據性別分別處理缺失值並用 KNN 補值
#     101 data_gender_1 = handle_outliers_and_impute(data[data['gender'] == 1], 1)
#
# Cell In[46], line 75, in replace_outliers_with_nan(data, index, column)
#      73 def replace_outliers_with_nan(data, index, column):
#      74     # 找到 outlier 值的索引
# ---> 75     outlier_value = data.loc[index, column]
#      77     # 將 outlier 值替換為 NaN
#      78     data.at[index, column] = np.nan
#
# File D:\Anaconda3\Lib\site-packages\pandas\core\indexing.py:1096, in _LocationIndexer.__getitem__(self, key)
#    1094     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1095     if self._is_scalar_access(key):
# -> 1096         return self.obj._get_value(*key, takeable=self._takeable)
#    1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#
# File D:\Anaconda3\Lib\site-packages\pandas\core\frame.py:3870, in DataFrame._get_value(self, index, col, takeable)
#    3867     series = self._ixs(col, axis=1)
#    3868     return series._values[index]
# -> 3870 series = self._get_item_cache(col)
#    3871 engine = self.index._engine
#    3873 if not isinstance(self.index, MultiIndex):
#    3874     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3875     #  results if our categories are integers that dont match our codes
#    3876     # IntervalIndex: IntervalTree has no get_loc
#
# File D:\Anaconda3\Lib\site-packages\pandas\core\frame.py:4255, in DataFrame._get_item_cache(self, item)
#    4250 res = cache.get(item)
#    4251 if res is None:
#    4252     # All places that call _get_item_cache have unique columns,
#    4253     #  pending resolution of GH#33047
# -> 4255     loc = self.columns.get_loc(item)
#    4256     res = self._ixs(loc, axis=1)
#    4258     cache[item] = res
#
# File D:\Anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'your_column'
